# %%
from fbprophet import Prophet
import pandas as pd 
import numpy as np

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
# load data sets
houston = pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Module 4\mod 4 final project\houston_prophet.csv')
midland = pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Module 4\mod 4 final project\midland_prophet.csv')
bakersfield = pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Module 4\mod 4 final project\bakersfield_prophet.csv')
bakersfield_original = pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Module 4\mod 4 final project\Bakersfield.csv')
midland_original = pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Module 4\mod 4 final project\Midland.csv')
houston_original= pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Module 4\mod 4 final project\Houston.csv')

# %%
houston
# Out:
#      Unnamed: 0          ds          y    y_orig
# 0             1  1996-05-01  12.255815  210200.0
# 1             2  1996-06-01  12.261980  211500.0
# 2             3  1996-07-01  12.268108  212800.0
# 3             4  1996-08-01  12.273731  214000.0
# 4             5  1996-09-01  12.279323  215200.0
# ..          ...         ...        ...       ...
# 142         143  2008-03-01  12.665394  316600.0
# 143         144  2008-04-01  12.666342  316900.0
# 144         145  2008-05-01  12.664446  316300.0
# 145         146  2008-06-01  12.662864  315800.0
# 146         147  2008-07-01  12.667918  317400.0
#
# [147 rows x 4 columns]

# %%
houston.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
model = Prophet() #instantiate Prophet
model.fit(houston); #fit the model with your dataframe
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_houston = model.make_future_dataframe(periods=12, freq = 'm')

# %%
forecast_data = model.predict(future_houston)

# %%
forecast_data[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 154 2009-02-28  12.733401   12.696264   12.776228
# 155 2009-03-31  12.732810   12.686725   12.784937
# 156 2009-04-30  12.733543   12.681901   12.791680
# 157 2009-05-31  12.733785   12.669779   12.805739
# 158 2009-06-30  12.740243   12.666486   12.822197

# %%
model.plot(forecast_data)

# %%
forecast_data.head()
# Out:
#           ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1996-05-01  12.259732   12.247247   12.272520    12.259732    12.259732
# 1 1996-06-01  12.263603   12.251044   12.277338    12.263603    12.263603
# 2 1996-07-01  12.267348   12.253146   12.279524    12.267348    12.267348
# 3 1996-08-01  12.271218   12.259315   12.284378    12.271218    12.271218
# 4 1996-09-01  12.275088   12.264148   12.289589    12.275088    12.275088
#
#    additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        0.000173              0.000173              0.000173  0.000173
# 1        0.000287              0.000287              0.000287  0.000287
# 2       -0.000968             -0.000968             -0.000968 -0.000968
# 3        0.000696              0.000696              0.000696  0.000696
# 4        0.000875              0.000875              0.000875  0.000875
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# ...

# %%
metric_houston= forecast_data.set_index('ds')[['yhat']].join(houston.set_index('ds').y).reset_index()

# %%
metric_houston
# Out:
#             ds       yhat          y
# 0   1996-05-01  12.259905  12.255815
# 1   1996-06-01  12.263889  12.261980
# 2   1996-07-01  12.266380  12.268108
# 3   1996-08-01  12.271914  12.273731
# 4   1996-09-01  12.275963  12.279323
# ..         ...        ...        ...
# 154 2009-02-28  12.733401        NaN
# 155 2009-03-31  12.732810        NaN
# 156 2009-04-30  12.733543        NaN
# 157 2009-05-31  12.733785        NaN
# 158 2009-06-30  12.740243        NaN
#
# [159 rows x 3 columns]

# %%
metric_houston.dropna(inplace=True)

# %%
metric_houston.tail()
# Out:
#             ds       yhat          y
# 142 2008-03-01  12.676778  12.665394
# 143 2008-04-01  12.680384  12.666342
# 144 2008-05-01  12.685116  12.664446
# 145 2008-06-01  12.689320  12.662864
# 146 2008-07-01  12.692023  12.667918

# %%
r2_score(metric_houston.y, metric_houston.yhat)
# Out:
# 0.9928962666693935

# %%
mean_squared_error(metric_houston.y, metric_houston.yhat)
# Out:
# 9.824990361921544e-05

# %%
mean_absolute_error(metric_houston.y, metric_houston.yhat)
# Out:
# 0.006130080263527253

# %%
midland
# Out:
#              ds         y    y_orig
# 0    1996-05-01  0.897326  2.453035
# 1    1996-06-01  0.897295  2.452958
# 2    1996-07-01  0.897263  2.452881
# 3    1996-08-01  0.897232  2.452804
# 4    1996-09-01  0.897200  2.452726
# ..          ...       ...       ...
# 142  2008-03-01  0.909725  2.483639
# 143  2008-04-01  0.909704  2.483587
# 144  2008-05-01  0.909620  2.483379
# 145  2008-06-01  0.909451  2.482960
# 146  2008-07-01  0.909282  2.482538
#
# [147 rows x 3 columns]

# %%
midland.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
model_midland = Prophet() #instantiate Prophet
model_midland.fit(midland); #fit the model with your dataframe
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_midland = model_midland.make_future_dataframe(periods=12, freq = 'm')

# %%
forecast_midland = model_midland.predict(future_midland)

# %%
model_midland.plot(forecast_midland)

# %%
metric_midland= forecast_midland.set_index('ds')[['yhat']].join(midland.set_index('ds').y).reset_index()

# %%
metric_midland
# Out:
#             ds      yhat         y
# 0   1996-05-01  0.897385  0.897326
# 1   1996-06-01  0.897265  0.897295
# 2   1996-07-01  0.897191  0.897263
# 3   1996-08-01  0.897485  0.897232
# 4   1996-09-01  0.897357  0.897200
# ..         ...       ...       ...
# 154 2009-02-28  0.912348       NaN
# 155 2009-03-31  0.912661       NaN
# 156 2009-04-30  0.912991       NaN
# 157 2009-05-31  0.913312       NaN
# 158 2009-06-30  0.913572       NaN
#
# [159 rows x 3 columns]

# %%
metric_midland.dropna(inplace=True)

# %%
metric_midland.tail()
# Out:
#             ds      yhat         y
# 142 2008-03-01  0.909898  0.909725
# 143 2008-04-01  0.910117  0.909704
# 144 2008-05-01  0.910248  0.909620
# 145 2008-06-01  0.910401  0.909451
# 146 2008-07-01  0.910591  0.909282

# %%
r2_score(metric_midland.y, metric_midland.yhat)
# Out:
# 0.9950119057862691

# %%
mean_squared_error(metric_midland.y, metric_midland.yhat)
# Out:
# 5.5681226249015266e-08

# %%
mean_absolute_error(metric_midland.y, metric_midland.yhat)
# Out:
# 0.00014292086132660593

# %%
model_midland.plot_components(forecast_midland)

# %%
bakersfield.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
model_bakersfield = Prophet() #instantiate Prophet
model_bakersfield.fit(bakersfield); #fit the model with your dataframe
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_bakersfield = model_bakersfield.make_future_dataframe(periods=12, freq = 'm')

# %%
forecast_bakersfield = model_bakersfield.predict(future_bakersfield)

# %%
model_bakersfield.plot(forecast_bakersfield)

# %%
metric_bako = forecast_bakersfield.set_index('ds')[['yhat']].join(bakersfield.set_index('ds').y).reset_index()

# %%
metric_bako
# Out:
#             ds       yhat          y
# 0   1996-05-01  11.858335  11.868500
# 1   1996-06-01  11.854128  11.862173
# 2   1996-07-01  11.849323  11.855806
# 3   1996-08-01  11.858500  11.850112
# 4   1996-09-01  11.852233  11.845103
# ..         ...        ...        ...
# 154 2009-02-28  12.361560        NaN
# 155 2009-03-31  12.350297        NaN
# 156 2009-04-30  12.335735        NaN
# 157 2009-05-31  12.324472        NaN
# 158 2009-06-30  12.313044        NaN
#
# [159 rows x 3 columns]

# %%
metric_bako.dropna(inplace=True)

# %%
metric_bako.tail()
# Out:
#             ds       yhat          y
# 142 2008-03-01  12.546173  12.514292
# 143 2008-04-01  12.529602  12.487485
# 144 2008-05-01  12.516672  12.462264
# 145 2008-06-01  12.499619  12.438374
# 146 2008-07-01  12.482382  12.416334

# %%
r2_score(metric_bako.y, metric_bako.yhat)
# Out:
# 0.9970366441110509

# %%
mean_squared_error(metric_bako.y, metric_bako.yhat)
# Out:
# 0.00043329272890844114

# %%
mean_absolute_error(metric_bako.y, metric_bako.yhat)
# Out:
# 0.01194277063793757

# %%
model_bakersfield.plot_components(forecast_bakersfield)

# %%
houston_original.head()
# Out:
#    Unnamed: 0        Date     Price
# 0           1  1996-05-01  210200.0
# 1           2  1996-06-01  211500.0
# 2           3  1996-07-01  212800.0
# 3           4  1996-08-01  214000.0
# 4           5  1996-09-01  215200.0

# %%
houston_original.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
houston_original.rename(columns={houston_original.columns[0]: 'ds', houston_original.columns[1]: 'y'}, inplace=True)

# %%
model = Prophet() #instantiate Prophet
model.fit(houston_original); #fit the model with your dataframe
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_houston_original = model.make_future_dataframe(periods=12, freq = 'm')

# %%
forecast_data_houston_original = model.predict(future_houston_original)

# %%
model.plot(forecast_data_houston_original)

# %%
metric_houston_original= forecast_data_houston_original.set_index('ds')[['yhat']].join(houston_original.set_index('ds').y).reset_index()

# %%
metric_houston_original
# Out:
#             ds           yhat         y
# 0   1996-05-01  201060.709759  210200.0
# 1   1996-06-01  202488.736800  211500.0
# 2   1996-07-01  204686.846354  212800.0
# 3   1996-08-01  206978.881544  214000.0
# 4   1996-09-01  209447.323249  215200.0
# ..         ...            ...       ...
# 154 2009-02-28  317207.527513       NaN
# 155 2009-03-31  322357.932535       NaN
# 156 2009-04-30  323598.060047       NaN
# 157 2009-05-31  325158.293180       NaN
# 158 2009-06-30  325456.108178       NaN
#
# [159 rows x 3 columns]

# %%
metric_houston_original.dropna(inplace=True)

# %%
metric_houston_original.tail()
# Out:
#             ds           yhat         y
# 142 2008-03-01  318016.533092  316600.0
# 143 2008-04-01  316602.753051  316900.0
# 144 2008-05-01  317633.670979  316300.0
# 145 2008-06-01  317305.447370  315800.0
# 146 2008-07-01  317803.959521  317400.0

# %%
r2_score(metric_houston_original.y, metric_houston_original.yhat)
# Out:
# 0.9214756570436404

# %%
mean_squared_error(metric_houston_original.y, metric_houston_original.yhat)
# Out:
# 76941070.31812689

# %%
mean_absolute_error(metric_houston_original.y, metric_houston_original.yhat)
# Out:
# 7120.665059327734

# %%
bakersfield_original.head()
# Out:
#    Unnamed: 0        Date     Price
# 0           1  1996-05-01  142700.0
# 1           2  1996-06-01  141800.0
# 2           3  1996-07-01  140900.0
# 3           4  1996-08-01  140100.0
# 4           5  1996-09-01  139400.0

# %%
bakersfield_original.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
bakersfield_original.rename(columns={bakersfield_original.columns[0]: 'ds', bakersfield_original.columns[1]: 'y'}, inplace=True)

# %%
model_bakersfield = Prophet() #instantiate Prophet
model_bakersfield.fit(bakersfield_original); #fit the model with your dataframe
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_bakersfield_original = model_bakersfield.make_future_dataframe(periods=12, freq = 'm')

# %%
forecast_data_bakersfield_original = model_bakersfield.predict(future_bakersfield_original)

# %%
model_bakersfield.plot(forecast_data_bakersfield_original)

# %%
model_midland = Prophet() #instantiate Prophet
model_midland.fit(midland_original); #fit the model with your dataframe
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_midland_original = model_midland.make_future_dataframe(periods=12, freq = 'm')

# %%
forecast_data_midland_original = model_midland.predict(future_midland_original)

# %%
model_midland.plot(forecast_data_midland_original)

# %%
midland_original.head()
# Out:
#    Unnamed: 0        Date     Price
# 0           1  1996-05-01  111700.0
# 1           2  1996-06-01  111600.0
# 2           3  1996-07-01  111500.0
# 3           4  1996-08-01  111400.0
# 4           5  1996-09-01  111300.0

# %%
midland_original.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
midland_original.rename(columns={midland_original.columns[0]: 'ds', midland_original.columns[1]: 'y'}, inplace=True)
